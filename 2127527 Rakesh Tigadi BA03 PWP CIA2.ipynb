# %% [markdown]
# # ESKAPE.CLUB GETAWAY CABIN BOOKING MANAGMENT SYSTEM

# %% [markdown]
# ## Submitted By:
#                 Name : Rakesh Tigadi
#               Reg.No : 2127527
#               Class  : BA-03
#              Subject : PWP

# %% [markdown]
# ## Problem Statement
#
# There is requirement of exclusive digital system for getaway host to maintain Getaway cabin booking system along with the creation of the customer data base for future data analysis and also the separate file of customer payment details data.

# %% [markdown]
# ## Problem Objective
#     1) Create the customer Database in .TXT file
#     2) Maintain the checkin based on availability
#     3) Do Booking if cabin available and block the cabin
#     4) Create the payment details database in .TXT file
#     5) Create the booking Record  in .TXT file
#     6) Maintain the Checkout and Update the cabin to available
#     7) Generate the receipt for latest transaction only

# %% [markdown]
#  ## ER Diagram for ESKAPE.CLUB  GETAWAY CABIN BOOKING MANAGMENT SYSTEM
# ![2127527%20PWP%20CIA2%20ER%20Diagram-2.png](attachment:2127527%20PWP%20CIA2%20ER%20Diagram-2.png)

# %% [markdown]
# ## Process Flow Chart for ESKAPE.CLUB GETAWAY CABIN BOOKING MANAGMENT SYSTEM
# ![2127527%20PWP%20CIA2%20Flow%20Diagram.png](attachment:2127527%20PWP%20CIA2%20Flow%20Diagram.png)

# %%
while True:  #To run the loop continueosly
    print("Welcome to ESKAPE GETAWAY Cabin Booking System")
    print("Please provide Login credential")
    name = str(input("User Name: "))
    password = str(input("Enter Password: "))
    Login = open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\login password.txt",'r') 
    info = Login.read()
    info = info.split()
    if name in info:
        index = info.index(name) + 1
        usr_password = info[index]
        if usr_password == password:                    #Compare the entered credentials and access details in the file
            
            while True:
                
                print("Welcome to Eskape.Club")
                print("\n")
                
                print("        Welcome to ESKAPE GETAWAY Cabin Booking System     ")
                print("------------------------------------------------------")
                print("Enter 1. Enter Customer Detail and proceed with Checkin Process")
                print("Enter 2. Checkout and Update the availability of Cabin")
                print("Enter 3. To Logout from the System")
                
                choice = int(input())                  #Take the Input as per the display
                
                if (choice == 1):
                    
                    name=input("Enter customer name: ")
                    address=input("Enter customer's permanent address: ")
                    guests=int(input("Enter the number of guests: "))
                    cemail=input("Enter customer's email address: ")
                    aadhar=input("Enter customer's aadhar number: ")

                    import datetime 
                    current_time = datetime.datetime.now() #To get the current date and time

                    print("Here are the rates charged for Type of cabin to Experience Ultimate Getaway")
                    print("No_Mad   - Rs.2000 per night Getaway ")
                    print("Explorer - Rs 4000 per night Getaway ")
                    print("X        - Rs.6000 per night Getaway ")

                    cabintype=int(input("Enter Cabin Type preference By Customer : \n 1. No_Mad \n 2. Explorer \n 3. X \n "))
                    cabinno=0
                    count=0
                    i=0

                    #Cabin type:No-Mad
                    if cabintype==1:
                        Nomad=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\No_Mad.txt","r")
                        content=Nomad.readlines()
                        while i<len(content) and count<1:
                            if content[i]=="A\n":
                                cabinno=i+1
                                count+=1
                            i+=1
                        Nomad.close()

                        if count==1:
                            print("Nomad-",cabinno,' is available.')
                            answer=int(input("Should I proceed with booking? Type 1 to proceed. Else 0 to exit. "))

                            if answer==1:

                                #customer details text updation 
                                heading=['%10s %25s %50s %25s %25s %25s %25s' %("Cabin Number", "Name ", "Address ", "Email Id ", " Aadhar detail", "Cabin Type Opted","Checkin Time")+"\n"]
                                cust = open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\customerlist.txt", "a")
                                cust.write('%10s %25s %50s %25s %25s %25s %40s'%(str(cabinno),name, address, cemail, str(aadhar),"No-Mad", str(current_time)+"\n"))
                                cust.close()          
                                #payment
                                payments=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\payments.txt","a")
                                days=int(input("Enter the number of days of stay: "))

                                Bill=2000*days
                                Discount = 0.20*Bill
                                Amount= Bill-Discount
                                print("Total bill generated is Rs.",Bill)
                                print("After 20% discount Bill amount",Amount)

                                #payment database
                                payments=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\payments.txt","a")

                                payments.write("CREDIT")
                                payments.write("\n")
                                payments.write("Room number: ")
                                payments.write(str(cabinno))
                                payments.write("\n")
                                payments.write("Name: ")
                                payments.write(name)
                                payments.write("\n")
                                payments.write("EmailID: ")
                                payments.write(cemail)
                                payments.write("\n")
                                payments.write("Aadhar: ")
                                payments.write(aadhar)
                                payments.write("Cabin Type Selected: ")
                                payments.write("No-Mad")
                                payments.write("\n")
                                payments.write("Amount: ")
                                payments.write(str(Bill))
                                payments.write("\n")

                                paymode=int(input("Please select mode of payment: 1-cash, 2-card, 3-payment app- "))
                                payments.write("Mode of payment: ")
                                if paymode==1:
                                    payments.write("Cash")
                                    payments.write("\n")
                                if paymode==2:
                                    payments.write("Card")
                                    payments.write("\n")
                                if paymode==3:
                                    payments.write("Payment App")
                                    payments.write("\n")

                                payments.write("\n")
                                payments.close()   


                                Nomad=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\No_Mad.txt","r")
                                content=Nomad.readlines()
                                Nomad.close()

                                content[cabinno-1]="U\n"
                                Nomad=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\No_Mad.txt","w")
                                Nomad.writelines(content)
                                Nomad.close()

                                print("\n")
                                print("\n")

                                print("BOOKING CONFIRMED!!")
                                print("Name:",name)
                                print("Room number:",cabinno)
                                print("Room type: NO-Mad")
                                print("Please collect the receipt generated")




                                #Generating Record

                                rec=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\record.txt","a")
                                heading1=['%10s %25s %25s %25s' %("Name ","Cabin Number",  " Amount Paid", "Cabin Type")+"\n"]
                                
                                rec = open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\record.txt", "a")
                                
                                rec.write('%10s %25s %25s %25s '%(name,str(cabinno), Amount,"No-Mad" )+"\n")
                                rec.close()
                                
                                #Generating receipt 
                                
                                receipt=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\receipt.txt","w")
                                #Creating the record
                                heading1=['%10s %25s %25s %25s' %("Name ","Cabin Number",  " Amount Paid", "Cabin Type")+"\n"]
                                
                                receipt= open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\receipt.txt", "w")
                                receipt.writelines(heading1)
                                receipt.write('%10s %25s %25s %25s '%(name,str(cabinno), Amount,"No-Mad", )+"\n")
                                receipt.close() 

                            else:
                                    print("Thank You. See you soon.")
                        else:
                            print("No_mad Cabins are not available.")
                            
                            
                                #Cabin type:Explorer
                    if cabintype==2:
                        Explorer=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\Explorer.txt","r")
                        content=Explorer.readlines()
                        while i<len(content) and count<1:
                            if content[i]=="A\n":
                                cabinno=i+1
                                count+=1
                            i+=1
                        Explorer.close()
                        if count==1:
                            print("Explorer-",cabinno,' is available.')
                            answer=int(input("Should I proceed with booking? Type 1 to proceed. Else 0 to exit. "))
                            if answer==1:

                                #customer details text updation 
                                heading=['%10s %25s %50s %25s %25s %25s %25s' %("Cabin Number", "Name ", "Address ", "Email Id ", " Aadhar detail", "CabinType Opted","Checkin Time")+"\n"]
                                cust = open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\customerlist.txt", "a")
                                
                                cust.write('%10s %25s %50s %25s %25s %25s %40s'%(str(cabinno),name, address, cemail, str(aadhar), "Explorer", str(current_time)+"\n"))
                                cust.close() 


                                #payment
                                payments=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\payments.txt","a")
                                days=int(input("Enter the number of days of stay: "))

                                Bill=4000*days
                                Discount = 0.20*Bill
                                Amount= Bill-Discount
                                print("Total bill generated is Rs.",Bill)
                                print("After 20% discount Bill amount",Amount)


                                payments.write("CREDIT")
                                payments.write("\n")
                                payments.write("Room number: ")
                                payments.write(str(cabinno))
                                payments.write("\n")
                                payments.write("Name: ")
                                payments.write(name)
                                payments.write("\n")
                                payments.write("EmailID: ")
                                payments.write(cemail)
                                payments.write("\n")
                                payments.write("Aadhar: ")
                                payments.write(aadhar)
                                payments.write("\n")
                                payments.write("Cabin Type Selected: ")
                                payments.write("Explorer")
                                payments.write("Amount: ")
                                payments.write(str(Bill))
                                payments.write("\n")

                                paymode=int(input("Please select mode of payment: 1-cash, 2-card, 3-payment app- "))
                                payments.write("Mode of payment: ")
                                payments.write("\n")
                                if paymode==1:
                                    payments.write("Cash")
                                    payments.write("\n")
                                if paymode==2:
                                    payments.write("Card")
                                    payments.write("\n")
                                if paymode==3:
                                    payments.write("Payment App")
                                    payments.write("\n")
                                payments.write("\n")
                                payments.close()   


                                Explorer=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\Explorer.txt","r")
                                content=Explorer.readlines()
                                Explorer.close()

                                content[cabinno-1]="U\n"
                                Explorer=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\Explorer.txt","w")
                                Explorer.writelines(content)
                                Explorer.close()

                                print("\n")
                                print("\n")

                                print("BOOKING CONFIRMED!!")
                                print("Name:",name)
                                print("Room number:",cabinno)
                                print("Room type: Explorer")
                                print("Please collect the receipt generated \n \n \n")
                                
                                #Generating Record

                                rec=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\record.txt","a")
                                #Creating the record
                                heading1=['%10s %25s %25s %25s' %("Name ","Cabin Number",  " Amount Paid", "Cabin Type")+"\n"]
                                
                                rec = open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\record.txt", "a")
                                
                                rec.write('%10s %25s %25s %25s '%(name,str(cabinno), Amount,"Explorer", )+"\n")
                                rec.close()
                                
                                #Generating receipt 
                                
                                receipt=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\receipt.txt","w")
                                #Creating the record
                                heading1=['%10s %25s %25s %25s' %("Name ","Cabin Number",  " Amount Paid", "Cabin Type")+"\n"]
                                
                                receipt= open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\receipt.txt", "a")
                                receipt.writelines(heading1)
                                receipt.write('%10s %25s %25s %25s '%(name,str(cabinno), Amount,"Explorer", )+"\n")
                                receipt.close()

                            else:
                                    print("Thank You. See you soon.")
                        else:
                            print("Explorer Cabins are not available.")

                #Cabin type:X
                    if cabintype==3:
                        X=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\X.txt","r")
                        content=X.readlines()
                        while i<len(content) and count<1:
                            if content[i]=="A\n":
                                cabinno=i+1
                                count+=1
                            i+=1
                        X.close()
                        if count==1:
                            print("X -",cabinno,' is available.')
                            answer=int(input("Should I proceed with booking? Type 1 to proceed. Else 0 to exit. "))
                            if answer==1:

                                #customer details text updation 

                                cust=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\customerlist.txt","a")
                                heading=['%10s %25s %50s %25s %25s %25s %25s' %("Cabin Number", "Name ", "Address ", "Email Id ", " Aadhar detail", "Cabin Type Opted","Checkin Time")+"\n"]
                                cust = open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\customerlist.txt", "a")
                                
                                cust.write('%10s %25s %50s %25s %25s %25s %40s'%(str(cabinno),name, address, cemail, str(aadhar),"X", str(current_time)+"\n"))
                                cust.close() 


                                #payment
                                payments=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\payments.txt","a")
                                days=int(input("Enter the number of days of stay: "))

                                Bill=6000*days
                                Discount = 0.20*Bill
                                Amount= Bill-Discount
                                print("Total bill generated is Rs.",Bill)
                                print("After 20% discount Bill amount",Amount)


                                payments.write("CREDIT")
                                payments.write("\n")
                                payments.write("Room number: ")
                                payments.write(str(cabinno))
                                payments.write("\n")
                                payments.write("Name: ")
                                payments.write(name)
                                payments.write("\n")
                                payments.write("EmailID: ")
                                payments.write(cemail)
                                payments.write("\n")
                                payments.write("Aadhar: ")
                                payments.write(aadhar)
                                payments.write("\n")
                                payments.write("Cabin Type Selected: ")
                                payments.write("X")
                                payments.write("Amount: ")
                                payments.write(str(Bill))
                                payments.write("\n")

                                paymode=int(input("Please select mode of payment: 1-cash, 2-card, 3-payment app- "))
                                payments.write("Mode of payment: ")
                                payments.write("\n")
                                if paymode==1:
                                    payments.write("Cash")
                                    payments.write("\n")
                                if paymode==2:
                                    payments.write("Card")
                                    payments.write("\n")
                                if paymode==3:
                                    payments.write("Payment App")
                                    payments.write("\n")
                                payments.write("\n")
                                payments.close()   


                                X=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\X.txt","r")
                                content=X.readlines()
                                X.close()

                                content[cabinno-1]="U\n"
                                X=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\X.txt","w")
                                X.writelines(content)
                                X.close()

                                print("\n")
                                print("\n")

                                print("BOOKING CONFIRMED!!")
                                print("Name:",name)
                                print("Room number:",cabinno)
                                print("Room type: X")
                                print("Please collect the receipt generated \n \n \n")


                                #Generating Record

                                rec=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\record.txt","a")
                                #Creating the record
                                heading1=['%10s %25s %50s %25s' %("Name ","Cabin Number",  " Amount Paid", "Cabin Type")+"\n"]
                                
                                rec = open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\record.txt", "a")
                                
                                rec.write('%10s %25s %25s  %25s '%(name,str(cabinno), Amount,"X", )+"\n")
                                rec.close()
                                
                                #Generating receipt 
                                
                                receipt=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\receipt.txt","w")
                                #Creating the record
                                heading1=['%10s %25s %25s %25s' %("Name ","Cabin Number",  " Amount Paid", "Cabin Type")+"\n"]
                                
                                receipt= open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\receipt.txt", "a")
                                receipt.writelines(heading1)
                                receipt.write('%10s %25s %25s %25s '%(name,str(cabinno), Amount,"X", )+"\n")
                                receipt.close()
                                

                            else:
                                    print("Thank You. See you soon.")
                        else:
                            print("X Cabins are not available.")
                
                elif (choice==2):
                    cabintype=int(input("enter the Cabin Type: \n 1- No-Mad \n 2- Explorer \n 3- X "))
                    cabin=int(input("enter the cabin No"))
                    
                    if cabintype == 1:                       
                        Nomad=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\No_Mad.txt","r")
                        content=Nomad.readlines()
                        Nomad.close()
                        content[cabin-1]="A\n"
                        Nomad=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\No_Mad.txt","w")
                        Nomad.writelines(content)
                        Nomad.close()
                        print("Checkout and updation Completed")
                    if cabintype==2:
                        Explorer=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\Explorer.txt","r")
                        content=Explorer.readlines()
                        Explorer.close()
                        content[cabin-1]="A\n"
                        Explorer=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\Explorer.txt","w")
                        Explorer.writelines(content)
                        Explorer.close()
                        print("Checkout and updation Completed")
                        
                    if cabintype==3:
                        X=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\X.txt","r")
                        content=X.readlines()
                        X.close()
                        content[cabin-1]="A\n"
                        X=open("C:\\Users\Rakesh  Tigadi\\Desktop\\2127527 Getaway cabin booking system\\X.txt","w")
                        X.writelines(content)
                        X.close()
                        print("Checkout and updation Completed")
                    
                elif (choice==3):
                    print("Logged Out")
                    print("\n")
                    print("\n")
                    print("\n")
                    break
                
                else:
                    print("Please select correct option")
                    print("\n")
                    print("\n")
                    break
# Out:
# Welcome to ESKAPE GETAWAY Cabin Booking System
# Please provide Login credential
# User Name: Rakesh
# Enter Password: Tigadi
# Welcome to Eskape.Club
#
#
#         Welcome to ESKAPE GETAWAY Cabin Booking System
# ------------------------------------------------------
# Enter 1. Enter Customer Detail and proceed with Checkin Process
# Enter 2. Checkout and Update the availability of Cabin
# Enter 3. To Logout from the System
# 1
# Enter customer name: Virupaxappa
# Enter customer's permanent address: Tigadi House Dharwad
# Enter the number of guests: 2
# Enter customer's email address: vvtigadi@gmail.com
# Enter customer's aadhar number: 1234567890
# Here are the rates charged for Type of cabin to Experience Ultimate Getaway
# No_Mad   - Rs.2000 per night Getaway
# Explorer - Rs 4000 per night Getaway
# X        - Rs.6000 per night Getaway
# Enter Cabin Type preference By Customer :
#  1. No_Mad
#  2. Explorer
#  3. X
#  1
# Nomad- 1  is available.
# ...

# %%
## Conclusion 

Achieved the solution for the following objectives by the learnings from the classroom

    1) Created the customer Database in .TXT file
    2) Searched the availabe cabin and showed the availability with cabin Number.
    3) If choosen cabin is availble then will proceed with booking and updated the availble to Unavailable in .txt File.
    4) Generated the payment details data in .TXT file
    5) Generrated the booking Record  in .TXT file
    6) Maintain the Checkout and Updated the cabin unavailable to available.
    7) Generated the receipt for latest transaction only.
